# %%
library(tidyverse)
library(rvest)
library(readr)
library(skimr)
library(visdat)
library(purrr)
library(stringr)
library(glue)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.3.6     v purrr   0.3.4
# v tibble  3.1.8     v dplyr   1.0.9
# v tidyr   1.2.0     v stringr 1.4.1
# v readr   2.1.2     v forcats 0.5.1
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Attaching package: 'rvest'
#
#
# The following object is masked from 'package:readr':
#
#     guess_encoding

# %%
df = read_csv("https://data-atgis.opendata.arcgis.com/datasets/ATgis::average-daily-traffic-counts.csv?outSR=%7B%22latestWkid%22%3A2193%2C%22wkid%22%3A2193%7D")

df %>% select(-c(X, Y))
df
# Out:
# Rows: 11545 Columns: 24
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr  (7): road_name, start_name, end_name, latest, count_date, peak_hour, co...
# dbl (17): X, Y, OBJECTID, carr_way_no, road_id, location, adt, peaktraffic, ...
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#       OBJECTID carr_way_no road_id road_name
# 1      1       23788       50888   BRAMLEY DR
# 2      2       34813       70028   AWHITU RD
# 3      3          58       70028   AWHITU RD
# 4      4        1826       70028   AWHITU RD
# 5      5        1627       70028   AWHITU RD
# 6      6        1768       70028   AWHITU RD
# 7      7         133       70028   AWHITU RD
# 8      8        1512       70070   BROOK RD
# 9      9        1384       70121   COOPER RD (AWHITU)
# 10    10        1367       70129   CRAIG RD
# ...
